# %%
import logging
import VIIRS_tiled_granules

# %%
import logging

logger = logging.getLogger(__name__)

# %%
tile = "h08v05"
date_UTC = "2024-11-11"
tile_size = 2400
concept_ID = "C2631841556-LPCLOUD"
download_directory = "~/data/VIIRS_download"

# %%
results = VIIRS_tiled_granules.search_granules(
    concept_ID=concept_ID,
    date_UTC=date_UTC,
    tile=tile,
    tile_size=tile_size
)

remote_granule = results[0]
remote_granule
# Out:
# [2024-12-05 16:10:24 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2024-12-05 16:10:24 INFO]   VNP09GA.A2024316.h08v05.002.2024320161933
# [2024-12-05 16:10:24 INFO] Number of VIIRS 2 granules found using CMR search: 1
# Collection: {'ShortName': 'VNP09GA', 'Version': '002'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -115.3696, 'Latitude': 29.8308}, {'Longitude': -103.6998, 'Latitude': 29.9063}, {'Longitude': -117.3606, 'Latitude': 40.0852}, {'Longitude': -130.5407, 'Latitude': 40.0}, {'Longitude': -115.3696, 'Latitude': 29.8308}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-11-11T00:00:00.000Z', 'EndingDateTime': '2024-11-11T23:59:59.000Z'}}
# Size(MB): 68.19981002807617
# Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/VNP09GA.002/VNP09GA.A2024316.h08v05.002.2024320161933/VNP09GA.A2024316.h08v05.002.2024320161933.h5']

# %%
granule = VIIRS_tiled_granules.retrieve_granule(remote_granule, download_directory)
granule
# Out:
# [2024-12-05 16:10:24 INFO]  Getting 1 granules, approx download size: 0.07 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2024-12-05 16:10:24 INFO] File VNP09GA.A2024316.h08v05.002.2024320161933.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "filename": "~/data/VIIRS_download/VNP09GA.002/2024-11-11/VNP09GA.A2024316.h08v05.002.2024320161933.h5"
# }

# %%
granule.DN("SurfReflect_I1_1", "VIIRS_Grid_500m_2D")

# %%
granule.attributes("SurfReflect_I1_1", "VIIRS_Grid_500m_2D")
# Out:
# {'DIMENSION_LIST': array([array([<HDF5 object reference>], dtype=object),
#         array([<HDF5 object reference>], dtype=object)], dtype=object),
#  '_FillValue': np.int16(-28672),
#  'add_offset': np.float32(0.0),
#  'grid_mapping': np.bytes_(b'Projection'),
#  'long_name': np.bytes_(b'Imagery (375m) Surface Reflectance Band 1 - first layer'),
#  'scale_factor': np.float32(1e-04),
#  'units': np.bytes_(b'percent reflectance'),
#  'valid_range': array([ -100, 16000], dtype=int16)}

# %%
granule.layer("SurfReflect_I1_1", "VIIRS_Grid_500m_2D")

# %%
granule.fill("SurfReflect_I1_1", "VIIRS_Grid_500m_2D")
