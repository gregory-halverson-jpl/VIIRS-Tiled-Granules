# %%
import logging
import VIIRS_tiled_granules

# %%
import logging

logger = logging.getLogger(__name__)

# %%
tile = "h08v05"
date_UTC = "2024-11-11"
tile_size = 1200
concept_ID = "C2545314555-LPCLOUD"
download_directory = "~/data/VIIRS_download"

# %%
results = VIIRS_tiled_granules.search_granules(
    concept_ID=concept_ID,
    date_UTC=date_UTC,
    tile=tile,
    tile_size=tile_size
)

remote_granule = results[0]
remote_granule
# Out:
# [2024-12-05 16:07:01 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2024-12-05 16:07:01 INFO]   VNP21A1D.A2024316.h08v05.002.2024320160736
# [2024-12-05 16:07:01 INFO] Number of VIIRS 2 granules found using CMR search: 1
# Collection: {'ShortName': 'VNP21A1D', 'Version': '002'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -115.3696, 'Latitude': 29.8308}, {'Longitude': -103.6998, 'Latitude': 29.9063}, {'Longitude': -117.3606, 'Latitude': 40.0852}, {'Longitude': -130.5407, 'Latitude': 40.0}, {'Longitude': -115.3696, 'Latitude': 29.8308}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-11-11T00:00:00.000Z', 'EndingDateTime': '2024-11-11T23:59:59.000Z'}}
# Size(MB): 2.3955039978027344
# Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/VNP21A1D.002/VNP21A1D.A2024316.h08v05.002.2024320160736/VNP21A1D.A2024316.h08v05.002.2024320160736.h5']

# %%
granule = VIIRS_tiled_granules.retrieve_granule(remote_granule, download_directory)
granule
# Out:
# [2024-12-05 16:07:01 INFO]  Getting 1 granules, approx download size: 0.0 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2024-12-05 16:07:01 INFO] File VNP21A1D.A2024316.h08v05.002.2024320160736.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "filename": "~/data/VIIRS_download/VNP21A1D.002/2024-11-11/VNP21A1D.A2024316.h08v05.002.2024320160736.h5"
# }

# %%
granule.DN("LST_1KM", "VIIRS_Grid_Daily_1km_LST21")

# %%
granule.attributes("LST_1KM", "VIIRS_Grid_Daily_1km_LST21")
# Out:
# {'DIMENSION_LIST': array([array([<HDF5 object reference>], dtype=object),
#         array([<HDF5 object reference>], dtype=object)], dtype=object),
#  '_Fillvalue': array([0], dtype=uint16),
#  'add_offset': array([0.]),
#  'grid_mapping': np.bytes_(b'Projection'),
#  'long_name': np.bytes_(b'Daily 1km Land-surface Temperature'),
#  'scale_factor': array([0.02]),
#  'units': np.bytes_(b'K'),
#  'valid_range': array([ 7500, 65535], dtype=uint16)}

# %%
granule.layer("LST_1KM", "VIIRS_Grid_Daily_1km_LST21")

# %%
granule.fill("LST_1KM", "VIIRS_Grid_Daily_1km_LST21")
